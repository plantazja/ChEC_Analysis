# %%
import pandas as pd
import sys
import numpy as np

sys.path.append('../../scripts/3_signal_analysis')

from calculate import get_signals
from save import save_signals

# %% [markdown]
# ### **a) DMSO/IAA signals:** Calculate signals from .wig file from provided coordinates in .bed format

# %%
#################### EXAMPLE USAGE ####################
################ PASTE YOUR PATHS INSTEAD #############
output_dir = '../../results/signals_spikein/RDY374'

# When comparing signals from different conditions, use same coordinates
# In case DMSOvsIAA, it's common peaks from compare_peaks.ipynb
bed_path = '../../results/compared_peaks/RDY374_as_DMSO_25_nC_RDY374_as_IAA_25_nC/in_RDY374_as_IAA_25_nC_RDY374_as_DMSO_25_nC_ex.bed'

DMSO_wig_path = '../../data/wig/spikein_mean/RDY374_as_DMSO_25_nC_spikein_mean.wig'
IAA_wig_path = '../../data/wig/spikein_mean/RDY374_as_IAA_25_nC_spikein_mean.wig'

# Read files
coord = pd.read_csv(bed_path, names=['chr', 'start', 'end', 'center'], sep='\t', header=None)
DMSO_wig = pd.read_csv(DMSO_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')
IAA_wig = pd.read_csv(IAA_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/compat/_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'fsspec'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 15
#      13 coord = pd.read_csv(bed_path, names=['chr', 'start', 'end', 'center'], sep='\t', header=None)
#      14 DMSO_wig = pd.read_csv(DMSO_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')
# ---> 15 IAA_wig = pd.read_csv(IAA_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')
#
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/io/common.py:716, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     713     codecs.lookup_error(errors)
#     715 # open URLs
# --> 716 ioargs = _get_filepath_or_buffer(
#     717     path_or_buf,
#     718     encoding=encoding,
#     719     compression=compression,
#     720     mode=mode,
#     721     storage_options=storage_options,
#     722 )
#     724 handle = ioargs.filepath_or_buffer
#     725 handles: list[BaseBuffer]
#
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/io/common.py:393, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     391 if filepath_or_buffer.startswith("s3n://"):
#     392     filepath_or_buffer = filepath_or_buffer.replace("s3n://", "s3://")
# --> 393 fsspec = import_optional_dependency("fsspec")
#     395 # If botocore is installed we fallback to reading with anon=True
#     396 # to allow reads from public buckets
#     397 err_types_to_retry_with_anon: list[Any] = []
#
# File ~/Personal/ChEC-seq_Peak_Calling_Merging_Analysing/venv/lib/python3.9/site-packages/pandas/compat/_optional.py:145, in import_optional_dependency(name, extra, errors, min_version)
#     143 except ImportError:
#     144     if errors == "raise":
# --> 145         raise ImportError(msg)
#     146     return None
#     148 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'fsspec'.  Use pip or conda to install fsspec.

# %%
DMSO_signals = get_signals(coord, DMSO_wig)
IAA_signals = get_signals(coord, IAA_wig)

# Save signals
save_signals(signals=DMSO_signals,
            in_file_path=DMSO_wig_path,
            out_dir_path=output_dir)
save_signals(signals=IAA_signals,
            in_file_path=IAA_wig_path,
            out_dir_path=output_dir)

# Clean cache, otherwise will crash
del coord, DMSO_wig, IAA_wig

# %% [markdown]
# ### **b) Sample without treatment** - cpm signals

# %%
#################### EXAMPLE USAGE ####################
################ PASTE YOUR PATHS INSTEAD #############
output_dir = '../../results/signals_cpm/RDY412'

# coordinates path
bed_path = '../../results/merged_peaks/RDY412/RDY412_as_unTr_nT_nC.bed'
# signals path
wig_path = '../../data/wig/cpm_mean/RDY412_as_unTr_nT_nC_cpm_mean.wig'

# Read files
coord = pd.read_csv(bed_path, names=['chr', 'start', 'end', 'center'], sep='\t', header=None)
wig = pd.read_csv(wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')

# %%
signals = get_signals(coord, wig)

# Save signals
save_signals(signals=signals,
            in_file_path=wig_path, # used to name new .csv file
            out_dir_path=output_dir)

# Clean cache, otherwise will crash
del coord, wig

# %% [markdown]
# ### **c) Signals from 4 different stages of cell cycle - asyn, G1, S, G2/M** - cpm signals

# %%
#################### EXAMPLE USAGE ####################
################ PASTE YOUR PATHS INSTEAD #############
output_dir = '../results/signals_cpm/RDY412'

# When comparing signals from different conditions, use same coordinates
# In case phases, it's common peaks from all phases from compare_peaks.ipynb
bed_path = '../results/compared_peaks/RDY..'

as_wig_path = '../../data/wig/cpm_mean/RDY412_as_unTr_nT_nC_cpm_mean.wig'
G1_wig_path = '../../data/wig/cpm_mean/RDY412_G1_unTr_nT_nC_cpm_mean.wig'
S_wig_path = '../../data/wig/cpm_mean/RDY412_S_unTr_nT_nC_cpm_mean.wig'
G2_wig_path = '../../data/wig/cpm_mean/RDY412_G2_unTr_nT_nC_cpm_mean.wig'

# Read files
coord = pd.read_csv(bed_path, names=['chr', 'start', 'end', 'center'], sep='\t', header=None)

as_wig = pd.read_csv(as_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')
G1_wig = pd.read_csv(G1_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')
S_wig = pd.read_csv(S_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')
G2_wig = pd.read_csv(G2_wig_path, names=['chr', 'start', 'end', 'signal'], sep='\t', header=None, comment='#')

# %%
as_signals = get_signals(coord, as_wig)
G1_signals = get_signals(coord, G1_wig)
S_signals = get_signals(coord, S_wig)
G2_signals = get_signals(coord, G2_wig)

# Save signals
save_signals(signals=as_signals,
            in_file_path=as_wig_path,
            out_dir_path=output_dir)

save_signals(signals=G1_signals,
            in_file_path=G1_wig_path,
            out_dir_path=output_dir)

save_signals(signals=S_signals,
            in_file_path=S_wig_path,
            out_dir_path=output_dir)

save_signals(signals=G2_signals,
            in_file_path=G2_wig_path,
            out_dir_path=output_dir)

# Clean cache, otherwise will crash
del coord, as_wig, G1_wig, S_wig, G2_wig
